# %% [markdown]
# <a href="https://colab.research.google.com/github/ganzigood/colab_repo/blob/main/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 직선 그래프 (Line plot) 를 그려보세요

# %%
# plt.plot(x, y) 함수를 사용하여 다음과 같은 그래프를 그려본다
# x, y 축을 갖는 그래프
# x 축 0, 1,2,3,...9
# y 축 x ** 2

# code here

# %% [markdown]
# #### 스타일 지정
# - plt.plot(x, y, style)
#
#   ![image.png](data:image/png;base64,...)

# %%
# plt.plot(x, y, style) 함수를 사용하여 다음과 같은 그래프를 그려보세요
# x, y 축을 갖고, 빨간색 원('ro')으로 표시되는 그래프
# x 축 0, 1,2,3,...9
# y 축 x ** 2

# code here

# %%
# 참고 : 마커크기는 ms=50
# code here

# %% [markdown]
# #### 여러 그래프를 겹쳐 그려보세요

# %%
# 여러 그래프 겹쳐 그리기
# x 축 0, 1,2,3,...9
# y 축 x*2, x**2, x**3
# 파란색 : b ,  빨간색 r, 녹색: g
# 라인 -, 점선 -- , 점 O

# code here
x = np.arange(10)
plt.plot(x, x*2, 'b-', x, x**2, 'r--', x, x**3, 'go')
# Out:
# [<matplotlib.lines.Line2D at 0x7e99a829e9e0>,
#  <matplotlib.lines.Line2D at 0x7e99a829e9b0>,
#  <matplotlib.lines.Line2D at 0x7e99a829eb90>]

# %%
# 다음 출력과 같이 레이블과 제목을 표시해보세요.
x = np.arange(10)
plt.plot(x, x*2, 'b-', x, x**2, 'r--', x, x**3, 'go')


# code here
# Out:
# Text(0.5, 1.0, 'time for money')

# %% [markdown]
# #### 전체데이터 중에 특정 영역만 표시해보세요.
# - 참고
# - plt.xlim(min, max)
# - plt.ylim(min, max)

# %%
# 전체 데이터 중 특정 영역만 표시해 본다
x = np.arange(10)  # 0~9
y = x ** 2         # 0~81
plt.plot(x, y)

# x 축에 대해서 2~5, y축에 대해서 5~20 영역 표시해보세요.


# code here
# Out:
# (5.0, 20.0)

# %% [markdown]
# #### Legend(범례)를 표시해보세요.

# %%
# Legend(범례)
x = np.arange(10)
y = x ** 2
y2 = x*5 + 2
# 다음과 같은 결과로 범례가 표시되도록 plt.plot의 label, plt.legend의 loc을 지정해 보도록 한다

# code here

# %% [markdown]
# ### Subplot을 이용해서 여러 plot을 나누어 표시해보세요.

# %%
# subplot
x = np.arange(0, 10, 0.1)
# 순서대로  x**2 , x*5,  np.sin(), np.cos()


# code here

# %% [markdown]
# ###  Scatter (산점도, 산포도, 분산 형 차트) 를 그려보세요.
# - plt.scatter(x, y, s, c, alpha)
#    - s : scale
#    - c : color
#    - alpha : 투명도(0~1)

# %%
x = np.arange(50)
y = x + np.random.rand(50) * 10
magnitude = np.random.randint(1, 100, 50)
category = np.random.randint(0, 5, 50)


# code here

# %% [markdown]
# ### Bar 그래프 (막대그래프) 를 그려보세요.
# - plt.bar(x, y)
# - plt.barh(x, y)

# %%
names = ['A', 'B', 'C']    # x축값
values=[50, 30, 100]       # y축값

#  code here
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### 히스토그램 (Histogram) 을 그려보세요.
# - n, bins, patches = plt.hist(x, bins, range)
#     - x : 데이터
#     - bins : 계급
#     - range(대상 범위)
#     - n : 도수
#     - patches : 계급별 히스토그램 좌표와 높이

# %%
x = 100 + 15 *np.random.randn(10000)

# code here

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# code here

# %% [markdown]
# ### 박스플랏(Boxplot)
# - plt.boxplot(x)
# - 최소값, 제 1사분위수, 제 2사분위수, 제 3사분위수 , 최대값
# - ![image.png](data:image/png;base64,...)

# %%
import seaborn as sns
iris = sns.load_dataset("iris")  # 붓꽂
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.boxplot(iris['sepal_length'])
plt.show()

# %%
plt.boxplot([iris['sepal_length'], iris['sepal_width']])
plt.show()

# %%
iris.plot.box()
# Out:
# <Axes: >
